# %% [markdown]
# # Eksplorasi llm-from-scratch
#
# Notebook ini berisi eksperimen awal untuk model transformer sederhana.

# %%
# !nvidia-smi
# Out:
# Sat May  9 10:43:28 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8             13W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !git clone https://github.com/simon/llm-from-scratch.git
# Out:
# Cloning into 'llm-from-scratch'...
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git clone https://github.com/makarivmri12/llm-from-scratch.git
# Out:
# Cloning into 'llm-from-scratch'...
# remote: Enumerating objects: 54, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 54 (delta 7), reused 51 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (54/54), 12.16 KiB | 2.03 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
# !python train.py
# Out:
# python3: can't open file '/content/llm-from-scratch/train.py': [Errno 2] No such file or directory

# %%
# !pip install -r requirements.txt

# %%
# %cd llm-from-scratch
# Out:
# /content/llm-from-scratch/llm-from-scratch

# %%
# !python train.py
# Out:
# python3: can't open file '/content/llm-from-scratch/llm-from-scratch/train.py': [Errno 2] No such file or directory

# %%
# !ls -F
# Out:
# configs/  notebooks/  requirements.txt	setup.py  tests/
# data/	  README.md   scripts/		src/

# %%
cd llm-from-scratch
# Out:
# [Errno 2] No such file or directory: 'llm-from-scratch'
# /content/llm-from-scratch/llm-from-scratch

# %%
# %cd ..
# Out:
# /

# %%
# %cd /content/llm-from-scratch
# Out:
# [Errno 2] No such file or directory: '/content/llm-from-scratch'
# /

# %%
# !ls -F /content/
# Out:
# sample_data/

# %%
# %cd /content/
# Out:
# /content

# %%
# !git clone https://github.com/makarivmri12/llm-from-scratch.git
# Out:
# Cloning into 'llm-from-scratch'...
# remote: Enumerating objects: 54, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 54 (delta 7), reused 51 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (54/54), 12.16 KiB | 2.43 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
# %cd llm-from-scratch
# Out:
# [Errno 2] No such file or directory: 'llm-from-scratch'
# /content/llm-from-scratch

# %%
# !python -m src.training
# Out:
# <frozen runpy>:128: RuntimeWarning: 'src.training' found in sys.modules after import of package 'src', but prior to execution of 'src.training'; this may result in unpredictable behaviour

# %%
# %cd llm-from-scratch
# Out:
# /content/llm-from-scratch

# %%
# !python -m src.training
# Out:
# <frozen runpy>:128: RuntimeWarning: 'src.training' found in sys.modules after import of package 'src', but prior to execution of 'src.training'; this may result in unpredictable behaviour

# %%
# !ls -F
# Out:
# configs/  notebooks/  requirements.txt	setup.py  tests/
# data/	  README.md   scripts/		src/

# %%
# !python -m src.training
# Out:
# /usr/bin/python3: Error while finding module specification for 'src.training' (ModuleNotFoundError: No module named 'src')

# %%
# %cd src/
# Out:
# /content/llm-from-scratch/llm-from-scratch/src

# %%
# !ls -F
# Out:
# data/  inference.py  __init__.py  model.py  tokenizer.py  training.py  utils/

# %%
# !python training.py
# Out:
# Traceback (most recent call last):
#   File "/content/llm-from-scratch/llm-from-scratch/src/training.py", line 4, in <module>
#     from .model import SimpleTransformer, TransformerConfig
# ImportError: attempted relative import with no known parent package
